# %% [markdown]
# ## Setup stuff

# %%
import numpy as np
import matplotlib.pyplot as plt
from pynq import allocate
from pynq import PL
PL.reset()
import xrfdc
from pynq import Overlay
ol = Overlay('./design_1.bit')
# sanity check that we are at 150 MHz
from pynq import Clocks
Clocks.pl_clk0_mhz = 150
print(Clocks.pl_clk0_mhz)
# Out:
# 150

# %%
rf = ol.usp_rf_data_converter_0
adc_tile = rf.adc_tiles[2]
adc_block = adc_tile.blocks[0]
adc_block.Dither = 0 #doesn't really matter for this lab, but let's turn off.
center_frequency = 1575.43
doppler = 0
adc_block.MixerSettings['Freq']= center_frequency + doppler / 1000 # set the frequency of the Numerically controlled oscillator.
adc_block.UpdateEvent(xrfdc.EVENT_MIXER) #every time setting is changed, must call this.
print(adc_block.MixerSettings)
# Out:
# {'Freq': 1575.429999999993, 'PhaseOffset': 0.0, 'EventSource': 2, 'CoarseMixFreq': 0, 'MixerMode': 3, 'FineMixerScale': 0, 'MixerType': 2}

# %%
N = 4096
num_width = 32

# %%
mmio_interface = ol.mmio_interface
dma_output = ol.axi_dma_0
dma_prn_config = ol.axi_prn_config
dma_iq_config = ol.axi_iq_config
dma_ifft_config = ol.axi_ifft_config

# %%
# set up ffts
fft_config = allocate(1, dtype=np.uint8)
fft_config[0] = 0
ifft_config = allocate(1, dtype=np.uint8)
ifft_config[0] = 1
# note they are default inverse (1)
dma_prn_config.sendchannel.transfer(fft_config)
dma_prn_config.sendchannel.wait()
dma_iq_config.sendchannel.transfer(fft_config)
dma_iq_config.sendchannel.wait()
dma_ifft_config.sendchannel.transfer(ifft_config)
dma_ifft_config.sendchannel.wait()

# %% [markdown]
# ## Functions

# %%
# numerical helpers
def get_twos_from_decimal(decimal, num_bits):
    decimal = int(decimal)
    return decimal % (1<<num_bits)

def get_value_from_complex(real, imag, num_bits):
    return get_twos_from_decimal(real, num_bits)*(1<<num_bits)+get_twos_from_decimal(imag, num_bits)

def get_decimal_from_twos(twos, num_bits):
    twos = int(twos)
    if twos >= (1<<(num_bits-1)):
        return twos - (1<<num_bits)
    else:
        return twos
    
def get_components(complex_array, num_bits):
    return {
        'real': np.array([get_decimal_from_twos(x // (1<<num_bits), num_bits) for x in complex_array]),
        'imag': np.array([get_decimal_from_twos(x % (1<<num_bits), num_bits) for x in complex_array])
    }

# %%
import time
def get_conv_data(): #outputs 1 code block
    mmio_interface.write(0x08, 0)
    res_data = allocate(2*N, dtype=np.uint32)
    time.sleep(0.0005)
    mmio_interface.write(0x08, 1)
    dma_output.recvchannel.transfer(res_data)
    dma_output.recvchannel.wait()
    return res_data

# %%
def doppler_sweep(prn_id, start = -8000, end = 8000, step = 100, scaling = 16): #sweeps frequency range
    doppler_range = list(range(start, end, step))
    mmio_interface.write(0x00, scaling)
    mmio_interface.write(0x04, prn_id-1)

    amplitudes = []
    for doppler in doppler_range:
        
        if doppler % 1000 == 0: print(f'on doppler {doppler}')
            
        # set adc frequency now
        adc_block.MixerSettings['Freq']= center_frequency + doppler / 1e6 # set the frequency of the Numerically controlled oscillator.
        adc_block.UpdateEvent(xrfdc.EVENT_MIXER) #every time setting is changed, must call this.
        
        res_data = get_conv_data()

        # now do calculation
        real = res_data[1::2]
        imag = res_data[0::2]
        real_decimal = [get_decimal_from_twos(x, num_width) for x in real]
        imag_decimal = [get_decimal_from_twos(x, num_width) for x in imag]
        convolve = np.array([x+y*1j for (x,y) in zip(real_decimal, imag_decimal)])
        peak_position = np.argmax(abs(convolve))
        amplitudes.append(abs(convolve)[peak_position]**2)

    plt.plot(doppler_range, amplitudes)
    best_doppler = np.argmax(amplitudes)
    return amplitudes

# %%
#doppler_sweep(2)

# %%
def prn_sweep(start = -5000, end = 5000, step = 100, scaling = 16): #sweeps all 37 prns
    full_data = []
    for i in range(1,38):
        amplitudes = doppler_sweep(i,start=start, end=end, step=step, scaling=scaling)
        full_data.append(amplitudes)
        print(f"Frequency sweep of prn ID {i}, max {max(amplitudes)}")        
    return full_data

# %%
full_data = prn_sweep()
# Out:
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 1, max 44432357.00000001
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 2, max 40249040.0
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 3, max 38176625.0
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 4, max 41449042.0
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 5, max 45526276.0
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 6, max 40408693.0
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 7, max 46352420.00000001
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 8, max 41041773.0
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 9, max 40127859.99999999
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 10, max 41051041.0
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 11, max 38524732.99999999
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 12, max 38217219.99999999
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 13, max 43312570.0
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 14, max 36369698.00000001
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 15, max 43721581.0
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 16, max 46760465.00000001
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 17, max 44003125.00000001
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 18, max 43687757.0
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 19, max 38173050.0
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 20, max 41122567.999999985
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 21, max 39686674.000000015
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 22, max 49065826.0
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 23, max 37649580.999999985
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 24, max 37544330.00000001
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 25, max 39604549.00000001
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 26, max 38881818.00000001
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 27, max 40382570.00000001
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 28, max 46559952.99999999
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 29, max 42543665.0
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 30, max 38210706.00000001
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 31, max 40631506.0
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 32, max 40198916.0
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 33, max 45847300.000000015
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 34, max 40911650.0
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 35, max 36412434.0
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 36, max 35757125.00000001
# on doppler -5000
# on doppler -4000
# on doppler -3000
# on doppler -2000
# on doppler -1000
# on doppler 0
# on doppler 1000
# on doppler 2000
# on doppler 3000
# on doppler 4000
# Frequency sweep of prn ID 37, max 36147050.0

# %%
full_data
# Out:
# [(124, 4400, 41439089.0),
#  (140, 6000, 40672450.000000015),
#  (33, -4700, 43803408.99999999),
#  (148, 6800, 39478057.0),
#  (20, -6000, 39614801.00000001),
#  (117, 3700, 39785330.0),
#  (114, 3400, 48895666.00000001),
#  (31, -4900, 40105256.00000001),
#  (70, -1000, 42320072.0),
#  (87, 700, 40231449.99999999),
#  (78, -200, 40355146.00000001),
#  (132, 5200, 43414290.00000001),
#  (115, 3500, 40674625.0),
#  (138, 5800, 39400648.999999985),
#  (65, -1500, 41859665.00000001),
#  (105, 2500, 41167905.99999999),
#  (143, 6300, 39855764.0),
#  (150, 7000, 38147473.999999985),
#  (143, 6300, 37658673.0),
#  (62, -1800, 46927961.0),
#  (147, 6700, 39209602.0),
#  (106, 2600, 48603497.00000001),
#  (156, 7600, 46775797.00000001),
#  (138, 5800, 40934602.0),
#  (149, 6900, 42417337.00000001),
#  (42, -3800, 41444584.0),
#  (28, -5200, 40173127.99999999),
#  (6, -7400, 41783200.0),
#  (11, -6900, 45587209.99999999),
#  (14, -6600, 44889268.0),
#  (128, 4800, 43920929.0),
#  (63, -1700, 44657941.0),
#  (77, -300, 43213887.99999999),
#  (60, -2000, 47023748.0),
#  (135, 5500, 38803664.0),
#  (59, -2100, 41573041.0),
#  (108, 2800, 39246344.99999999)]
